# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd '/content/drive/MyDrive/2022-1 ESAA'
# Out:
# /content/drive/MyDrive/2022-1 ESAA

# %%
# !echo "# 2022-1 ESAA" >> README.md
# !git init
# !git config --global user.email "dkepfflvpdrnls@naver.com"
# !git config --global user.name "Dkepffl"
# !git config --global user.password  "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"
# !git commit -m "first commit"
# !git branch -M main
# !git remote rm origin
# !git remote add origin https://Dkepffl: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@github.com/Dkepffl/2022-1-ESAA.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/2022-1 ESAA/.git/
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes not staged for commit:
# 	modified:   README.md
#
# no changes added to commit
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://Dkepffl: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@github.com/Dkepffl/2022-1-ESAA.git/'

# %%
#commit
# !git add for_commit.ipynb
# !git commit -m "for_commit 1.0.1"
# !git push -
# Out:
# On branch main
# Changes not staged for commit:
# 	modified:   README.md
#
# no changes added to commit
# fatal: The current branch main has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin main
