# %% [markdown]
# <a href="https://colab.research.google.com/github/Dkepffl/2022-1-ESAA/blob/main/Assignment/Assignment0325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 패키지 한 번에 호출
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 04 그래프 그리기
# - 사람의 눈은 한 번에 볼 수 있는 양이 정해져 있기 때문에, 데이터를 시각화하여 데이터의 숨겨진 패턴을 파악해야 한다.

# %% [markdown]
# ### | 04-1 데이터 시각화가 필요한 이유
# #####  [ **앤스콤 4분할 그래프(Anscombe's quartet)** 살펴보기 ]
# - 앤스콤 4분할 그래프 : 데이터를 시각화하지 않고 수치만 확인할 때 발생할 수 있는 '함정'을 보여주기 위해 만든 그래프
#   + 앤스콤 4분할 그래프를 구성하는 데이터 집합은 4개의 그룹으로 구성되어 있으며, 모든 그룹은 x, y 열을 가지고 있다.
#   + 이 4개의 구릅은 각각 평균, 분산과 같은 수치값이나 상관관계, 회귀선이 같다
#   + 따라서 **'데이터 그룹 1~4의 데이터는 모두 같을 것이다'** 라는 '함정'에 빠질 수 있다.
# - 그러나 앤스콤 4분할 그래프를 이용하여 데이터를 시각화하면 각 그룹이 서로 다른 데이터 패턴을 가지고 있다는 것을 쉽게 알 수 있다.

# %% [markdown]
# ##### [실습] 앤스콤 데이터 집합 불러온 후 그래프 그리기
#   1. 앤스콤 데이터 집합 불러오기 : seaborn 라이브러리의 load_dataset 메서드 활용
#   2. matplotlib 라이브러리 호출
#   3. 첫 번째 데이터 그룹을 추출
#   4. Plot 메서드로 선 그래프 그리기
#   5. Plot 메서드를 활용하여 점으로 그래프 그리기

# %%
# 1. 앤스콤 데이터 집합 불러오기
anscombe = sns.load_dataset("anscombe") # load_dataset 메서드에 문자열 anscombe을 전달
print(anscombe)
print(type(anscombe)) # DataFram
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# 2. matplotlib 라이브러리로 그래프 그리기
import matplotlib.pyplot as plt # matplot library 호출

# %%
# 3. 첫 번째 데이터 그룹을 추출
dataset_1 = anscombe[anscombe['dataset'] == 'I'] # 불린 인덱싱

# %%
# 4. Plot 메서드로 선 그래프 그리기
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
# 5. Plot 메서드를 활용하여 점으로 그래프 그리기
plt.plot(dataset_1['x'], dataset_1['y'], 'o') # 세 번째 인자를 o로 설정

# %% [markdown]
# ##### [ 앤스콤 데이터 집합 모두 사용해 그래프 만들기]
# - 모든 데이터 그룹에 대하여 그리는 방법에 대해 알아볼 것이다.
# - **matplotlib 라이브러리**로 그래프 그리기
#   + 전체 그래프가 위치할 기본틀을 만든다.
#   + 그래프를 그려 넣을 그래프 격자(grid)를 만든다.
#        ```python
#         add_subplot(size_of_row, size_of_column)
#         ```
#   + 격자에 그래프를 하나씩 추가한다. 그래프는 왼쪽에서 오른쪽 방향으로 추가된다.
#   + 격자의 첫 번째 행이 꽉 차면 두 번째 행에 그래프를 그러 넣는다.

# %% [markdown]
# ##### [실습] 한 번에 4개의 그래프 그리기

# %%
# 1.앤스콤 데이터프레임의 데이터를 불린 인덱싱으로 추출하여 저장
dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
# 2.그래프와 격자가 위치할 기본 틀 생성
fig = plt.figure()

# 3.add_subplot 메서드로 그래프 격자 추가
axesl = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
# 4.plot 메서드에 데이터를 전달하여 그래프 그리기
axesl.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')
fig

# %%
# 5.그래프 격자에 제목 추가
axesl.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")
fig

# %%
# 6.기본 틀(fig))에 제목 추가
fig.suptitle("Anscombe Data")
fig

# %%
# 7.그래프의 레이아웃 조절 : In this case, 글씨가 겹치는 문제 해결
fig.tight_layout()
fig

# %% [markdown]
# ### | 04-2 matplotlib 라이브러리 자유자재로 사용하기
# ##### [ 기초 그래프 그리기 ]
# - seaborn 라이브러리의 'tips 데이터 집합(어떤 식당에서 팁을 지불한 손님의 정보)' 활용

# %% [markdown]
# ##### [실습] 기초 그래프 그리기 - 히스토그램, 산점도, 상자 그림
# 1. 히스토그램 : 데이터프레임의 열 데이터 분포와 빈도를 살펴보기 위해 자주 사용하는 그래프. 변수를 하나만 사용하여 '일변량 그래프'라고 한다.
# 2. 산점도 그래프 : 변수 2개를 사용해서 데이터의 분포를 나타내는 그래프. '이변량 그래프'에 해당한다.
# 3. 상자 그림(박스 그래프) : 이산형 변수와 연속형 변수를 함께 사용하는 그래프
#    + 이산형 변수 : 명확하게 구분되는 값
#   + 연속형 변수 : 명확하게 셀 수 없는 범위의 값

# %%
# tips 데이터 집합 호출
# tips 데이터프레임은 지불 금액, 팁, 성별, 흡연 유무, 요일, 시간, 전체 인원 정보를 담고 있다.
tips = sns.load_dataset("tips")
print(tips.head( )) 
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
# 히스토그램 그리기

# 기본 틀과 그래프 격자 구성
fig = plt.figure( )
axes1 = fig.add_subplot(1, 1, 1)

# hist 메서드로 히스토그램 그리기
# bins : x 축의 간격
axes1.hist(tips['total_bill'], bins=10) 
axes1.set_title('Histogram of Total Bill') # 그래프 제목
axes1.set_xlabel('Frequency') # x축 제목
axes1.set_ylabel('Total Bill') # y축 제목
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# total_bill에 따른 tip의 분포를 나타내는 산점도 그리기

# 기본 틀과 그래프 격자 구성
scatter_plot = plt.figure( )
axes1 = scatter_plot.add_subplot(1, 1, 1)

# scatter 메서드
axes1.scatter(tips['total_bill'], tips['tip'])

# 그래프와 x축, y축 제목 설정
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 박스 그래프 그리기

# 기본 틀과 그래프 격자 구성
boxplot = plt.figure( )
axes1 = boxplot.add_subplot(1, 1, 1)

# boxplot 메서드
axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
               tips[tips['sex'] == 'Male']['tip']], labels=['Female', 'Male'])

# 그래프와 x축, y축 제목 설정
axesl.set_xlabel('Sex') 
axesl.set_ylabel('Tip') 
axesl.set_title('Boxplot of Tips by Sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ##### [ 다변량 그래프 그리기 ]
# - **다변량 그래프** : 3개 이상의 변수를 사용한 그래프

# %% [markdown]
# ##### [실습] 다변량 데이터로 다변량 그래프 그리기 - 산점도
#   1. 산점도 그래프에서 색상으로 성별을 구분
#   2. 문자열은 산점도 그래프의 색상을 지정하는 값으로 사용할 수 없다.
#   3. 따라서 0, 1과 같은 정수로 치환해야 한다.
#   4. 테이블 당 인원 수(size)를 점의 크기로 구분

# %%
# 여성(Female)인 경우 0을 반환하고 남성(Male)인 경우 1을 반환하는 함수
def recode_sex(sex):
  if sex == 'Female':
    return 0
  else:
    return 1

# %%
# recode_sex 메서드가 반환한 값(0, 1)을 데이터프레임에 추가
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
# 기본 틀과 그래프 격자 구성
boxplot = plt.figure( )
axes1 = boxplot.add_subplot(1, 1, 1)

# scatter 메서드
axes1.scatter(x = tips['total_bill'],
              y = tips['tip'],
              s = tips['size']*10,
              c = tips['sex_color'],
              alpha = 0.5) # s = 점의 크기, c = 점의 색상, alpha = 점의 투명도

# 그래프와 x축, y축 제목 설정
axesl.set_title('Total Bill vs Tip Colored by Sex and Sized by Size') 
axesl.set_xlabel('Total Bill') 
axesl.set_ylabel('Tip')
# Out:
# Text(12.950000000000003, 0.5, 'Tip')

# %% [markdown]
# ### | 04-3 seaborn 라이브러리 자유자재로 사용하기
#
# ##### [실습] 단변량 그래프 그리기 - 히스토그램
#   1. Seaborn 라이브러리로 히스토그램 그리기 : `subplots`, `distplot` 메서드 사용
#     + `subplots` : 기본 틀 생성
#     + `distplot` : 열 데이터를 전달하여 히스토그램 그리기
#     + `kde = False` : 밀집도 그래프 제외
#     + `hist = False` : 히스토그램 제외
#     + `rug = True` : 양탄자 그래프 추가

# %%
# tips 데이터 집합 호출
tips = sns.load_dataset('tips')

# %%
# 기본 틀 생성
ax = plt.subplots( )

# 열 데이터를 전달하여 히스토그램 그리기
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot') # 제목 설정
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
# 밀집도 그래프 제외하고 히스토그램 그리기 : kde = False

# 기본 틀 생성
ax = plt.subplots( )

# 열 데이터를 전달하여 히스토그램 그리기
ax = sns.distplot(tips['total_bill'], kde = False) 

# 제목 설정
ax.set_title('Total Bill Histogram') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
# 히스토그램 제외하고 밀집도 그래프만 그리기 : hist = False

# 기본 틀 생성
ax = plt.subplots( )

# 열 데이터를 전달하여 히스토그램 그리기
ax = sns.distplot(tips['total_bill'], hist = False) 

# 제목 설정
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit Probability')

# %%
# 양탄자 그래프 추가 : rug = True

# 기본 틀 생성
ax = plt.subplots( )

# 열 데이터를 전달하여 히스토그램 그리기
ax = sns.distplot(tips['total_bill'], rug = True) 

# 제목 설정
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
#   2. count 그래프 : 이산값을 나타낸 그래프

# %%
# count 그래프 그리기
# 기본 틀 생성
ax = plt.subplots( )

# count 메서드
ax = sns.countplot('day', data = tips)

# 제목 설정
ax.set_title('Day of the Week')
ax.set_xlabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Frequency')

# %% [markdown]
# ##### [실습] 다양한 종류의 이변량 그래프 그리기
#   1. Seaborn 라이브러리로 산점도 그래프 그리기 : `regplot` 메서드 사용
#     + `regplot` : 산점도 그래프와 회귀선을 함께 그릴 수 있다.
#     + `fig_reg = False` : 회귀선 제거

# %%
# 산점도 그래프와 회귀선 그리기

# 기본 틀 생성
ax = plt.subplots( )

# regplot 메서드
ax = sns.regplot(x = 'total_bill', y = 'tip', data = tips) 

# 제목 설정
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 회귀선 제거하고 산점도 그래프만 그리기

# 기본 틀 생성
ax = plt.subplots( )

# regplot 메서드
ax = sns.regplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False) 

# 제목 설정
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
#   2. 산점도 그래프와 히스토그램을 그려주는 `jointplot` 메서드
#     + x, y 인자에 원하는 열 이름 지정
#     + data 인자에는 데이터 프레임 지정
#     + 산점도 그래프는 점이 겹쳐 보일 경우 점을 구분하기 어렵다는 단점이 있다.
#     + 육각 그래프를 사용하면 산점도그래프의 데이터를 구분하기 쉽게 그릴 수 있다.
#       * 육각 그래프 : 2차원 표면에 육각형으로 데이터를 쌓아 표현하는 그래프
#       * 특정 데이터의 개수가 많아지면 점점 진한 색으로 표현된다.
#       * `kind = hex`

# %%
# 산점도 그래프와 히스토그램을 그리기
joint = sns.jointplot(x = 'total_bill', y = 'tip', data=tips) 

# x, y축, 그래프 이름 추가
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip') 
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize = 10, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
# 육각 그래프 그리기
hexbin = sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'hex')

# x, y축, 그래프 이름 추가
hexbin.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize = 10, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
#   3. 이차원 밀집도 그리기
#     + `kdeplot` 메서드 사용
#     + `shade = True` : 그래프에 음영 효과 제공

# %%
# 이차원 밀집도 그리기

# 기본 틀 생성
ax = plt.subplots( )

# kdeplot 메서드
ax = sns.kdeplot(data = tips['total_bill'],
                 data2=tips['tip'],
                 shade=True) # 음영효과

# 제목 설정
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %% [markdown]
#   4. 바 그래프 그리기
#     + 바 그래프 : 지정한 변수의 평균을 계산하여 그릴 수 있다.
#     + `barplot` 메서드를 사용한다.

# %%
# 시간에 따라 지불한 비용의 평균을 바 그래프로 나타내기

# 기본 틀 생성
ax = plt.subplots( )

# barplot 메서드
ax = sns.barplot(x = 'time', y = 'total_bill', data = tips)

# 제목 설정
ax.set_title('Bar plot of average total bill for time of dayp')
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
#   5. 박스 그래프 그리기
#     + 박스 그래프 : 최솟값, 1분위수, 중간값, 3분위수, 최댓값, 기상치 등 다양한 통계량을 한 번에 표현하는 그래프
#     + `boxplot` 메서드를 사용한다.
#     + 데이터 분산이 모호하게 표현된다는 단점이 있다.

# %%
# 박스 그래프 그리기

# 기본 틀 생성
ax = plt.subplots( )

# barplot 메서드
ax = sns.boxplot(x = 'time', y = 'total_bill', data = tips)

# 제목 설정
ax.set_title('Boxplot of average total bill by time of day')
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total bill')
# Out:
# Text(0, 0.5, 'Total bill')

# %% [markdown]
#   6. 바이올린 그래프 그리기
#     + 바이올린 그래프 : 박스 그래프에 커널 밀도를 추정한 그래프
#     + 박스 그래프의 형태를 바이올린 형태로 바꾼 그래프라고 생각할 수 있다.
#     + `violinplot` 메서드를 사용한다.

# %%
# 바이올린 그래프 그리기

# 기본 틀 생성
ax = plt.subplots( )

# barplot 메서드
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips)

# 제목 설정
ax.set_title('Violin plot of average total bill by time of day')
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total bill')
# Out:
# Text(0, 0.5, 'Total bill')

# %% [markdown]
#   7. 관계 그래프 그리기
#     + 관계 그래프 : 산점도 그랲, 이차원 밀집도 등 위에서 다룬 그래프를 종합한 그래프
#     + `pairplot` 메서드 사용
#     + 관계 그래프는 중복된 정보가 표현된다는 단점이 있는데, 중복된 그래프가 그려지는 위치를 직접 지정하여 원하는 그래프로 교체할 수 있다.

# %%
# 관계 그래프 그리기
fig = sns.pairplot(tips)

# %% [markdown]
# ##### [실습] 다변량 그래프 그리기

# %% [markdown]
# ### | 04-4 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# ### | 04-5 seaborn 라이브러리로 그래프 스타일 설정하기
